# %%
import torch
import numpy as np
from model import Autoencoder
from trainer import Trainer
from utils import load_mnist
import matplotlib.pyplot as plt

# %%
from argparse import Namespace

config = {
    "train_ratio": 0.8,
    "batch_size": 256,
    "n_epochs": 50,
    "verbose": 1,
    "btl_size": 2,
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(train_ratio=0.8, batch_size=256, n_epochs=50, verbose=1, btl_size=2)

# %%
train_x, train_y = load_mnist(is_train=True, flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(train_x, dim=0, index=indices).split(
    [train_cnt, valid_cnt]
)
train_y, valid_y = torch.index_select(train_y, dim=0, index=indices).split(
    [train_cnt, valid_cnt]
)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
import torch.optim as optim
import torch.nn as nn

model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config=config)
# Out:
# Epoch(1/50): train_loss=7.0446e-02  valid_loss=4.7903e-02  lowest_loss=4.7903e-02
# Epoch(2/50): train_loss=4.5346e-02  valid_loss=4.4214e-02  lowest_loss=4.4214e-02
# Epoch(3/50): train_loss=4.3481e-02  valid_loss=4.2998e-02  lowest_loss=4.2998e-02
# Epoch(4/50): train_loss=4.2175e-02  valid_loss=4.1944e-02  lowest_loss=4.1944e-02
# Epoch(5/50): train_loss=4.1519e-02  valid_loss=4.1177e-02  lowest_loss=4.1177e-02
# Epoch(6/50): train_loss=4.0773e-02  valid_loss=4.1321e-02  lowest_loss=4.1177e-02
# Epoch(7/50): train_loss=4.0620e-02  valid_loss=4.1267e-02  lowest_loss=4.1177e-02
# Epoch(8/50): train_loss=4.0482e-02  valid_loss=4.0436e-02  lowest_loss=4.0436e-02
# Epoch(9/50): train_loss=4.0109e-02  valid_loss=3.9915e-02  lowest_loss=3.9915e-02
# Epoch(10/50): train_loss=3.9730e-02  valid_loss=3.9866e-02  lowest_loss=3.9866e-02
# Epoch(11/50): train_loss=3.9465e-02  valid_loss=3.9479e-02  lowest_loss=3.9479e-02
# Epoch(12/50): train_loss=3.9379e-02  valid_loss=3.9181e-02  lowest_loss=3.9181e-02
# Epoch(13/50): train_loss=3.9053e-02  valid_loss=3.8740e-02  lowest_loss=3.8740e-02
# Epoch(14/50): train_loss=3.8960e-02  valid_loss=3.8682e-02  lowest_loss=3.8682e-02
# Epoch(15/50): train_loss=3.8325e-02  valid_loss=3.8447e-02  lowest_loss=3.8447e-02
# Epoch(16/50): train_loss=3.8268e-02  valid_loss=3.8225e-02  lowest_loss=3.8225e-02
# Epoch(17/50): train_loss=3.8055e-02  valid_loss=3.7957e-02  lowest_loss=3.7957e-02
# Epoch(18/50): train_loss=3.7706e-02  valid_loss=3.8225e-02  lowest_loss=3.7957e-02
# Epoch(19/50): train_loss=3.7629e-02  valid_loss=3.7680e-02  lowest_loss=3.7680e-02
# Epoch(20/50): train_loss=3.7391e-02  valid_loss=3.7848e-02  lowest_loss=3.7680e-02
# Epoch(21/50): train_loss=3.7392e-02  valid_loss=3.7506e-02  lowest_loss=3.7506e-02
# Epoch(22/50): train_loss=3.7341e-02  valid_loss=3.7509e-02  lowest_loss=3.7506e-02
# Epoch(23/50): train_loss=3.6935e-02  valid_loss=3.7220e-02  lowest_loss=3.7220e-02
# Epoch(24/50): train_loss=3.6944e-02  valid_loss=3.7353e-02  lowest_loss=3.7220e-02
# Epoch(25/50): train_loss=3.6887e-02  valid_loss=3.7276e-02  lowest_loss=3.7220e-02
# Epoch(26/50): train_loss=3.6879e-02  valid_loss=3.7018e-02  lowest_loss=3.7018e-02
# Epoch(27/50): train_loss=3.6724e-02  valid_loss=3.7006e-02  lowest_loss=3.7006e-02
# Epoch(28/50): train_loss=3.6607e-02  valid_loss=3.7098e-02  lowest_loss=3.7006e-02
# Epoch(29/50): train_loss=3.6603e-02  valid_loss=3.6841e-02  lowest_loss=3.6841e-02
# Epoch(30/50): train_loss=3.6686e-02  valid_loss=3.6798e-02  lowest_loss=3.6798e-02
# Epoch(31/50): train_loss=3.6764e-02  valid_loss=3.6825e-02  lowest_loss=3.6798e-02
# Epoch(32/50): train_loss=3.6473e-02  valid_loss=3.6575e-02  lowest_loss=3.6575e-02
# Epoch(33/50): train_loss=3.6420e-02  valid_loss=3.6637e-02  lowest_loss=3.6575e-02
# Epoch(34/50): train_loss=3.6256e-02  valid_loss=3.6199e-02  lowest_loss=3.6199e-02
# Epoch(35/50): train_loss=3.6055e-02  valid_loss=3.6304e-02  lowest_loss=3.6199e-02
# Epoch(36/50): train_loss=3.5969e-02  valid_loss=3.6353e-02  lowest_loss=3.6199e-02
# Epoch(37/50): train_loss=3.6007e-02  valid_loss=3.6399e-02  lowest_loss=3.6199e-02
# Epoch(38/50): train_loss=3.5990e-02  valid_loss=3.6130e-02  lowest_loss=3.6130e-02
# Epoch(39/50): train_loss=3.5762e-02  valid_loss=3.6180e-02  lowest_loss=3.6130e-02
# Epoch(40/50): train_loss=3.5768e-02  valid_loss=3.5914e-02  lowest_loss=3.5914e-02
# Epoch(41/50): train_loss=3.5906e-02  valid_loss=3.6430e-02  lowest_loss=3.5914e-02
# Epoch(42/50): train_loss=3.6534e-02  valid_loss=3.6534e-02  lowest_loss=3.5914e-02
# Epoch(43/50): train_loss=3.6523e-02  valid_loss=3.6602e-02  lowest_loss=3.5914e-02
# Epoch(44/50): train_loss=3.6251e-02  valid_loss=3.6364e-02  lowest_loss=3.5914e-02
# Epoch(45/50): train_loss=3.6039e-02  valid_loss=3.6115e-02  lowest_loss=3.5914e-02
# Epoch(46/50): train_loss=3.5769e-02  valid_loss=3.5711e-02  lowest_loss=3.5711e-02
# Epoch(47/50): train_loss=3.5671e-02  valid_loss=3.5779e-02  lowest_loss=3.5711e-02
# Epoch(48/50): train_loss=3.5346e-02  valid_loss=3.5812e-02  lowest_loss=3.5711e-02
# Epoch(49/50): train_loss=3.5796e-02  valid_loss=3.5624e-02  lowest_loss=3.5624e-02
# Epoch(50/50): train_loss=3.6132e-02  valid_loss=3.6380e-02  lowest_loss=3.5624e-02

# %% [markdown]
# # Test

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** 0.5), -1)
    plt.imshow(x, cmap="gray")
    plt.show()

# %%
model.eval()

with torch.no_grad():
    import random

    index = int(random.random() * test_x.size(0))
    recon = model(test_x[index].view(1, -1)).squeeze()
    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# # Latent Space

# %%
if config.btl_size == 2:
    color_map = [
        "brown",
        "red",
        "orange",
        "yellow",
        "green",
        "blue",
        "navy",
        "purple",
        "gray",
        "black",
    ]

    plt.figure(figsize=(20, 10))
    model.eval()
    with torch.no_grad():
        latents = model.encoder(test_x[:1000])

        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y[:1000] == i]
            plt.scatter(
                target_latents[:, 0],
                target_latents[:, 1],
                marker="o",
                color=color_map[i],
                label=i,
            )
        plt.legend()
        plt.grid(axis="both")
        plt.show()

# %%
if config.btl_size == 2:
    min_range, max_range = -2.0, 2.0
    n = 20
    step = (max_range - min_range) / float(n)

    with torch.no_grad():
        lines = []

        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack(
                [
                    torch.FloatTensor([v1] * n),
                    torch.FloatTensor(
                        [v2 for v2 in np.arange(min_range, max_range, step)]
                    ),
                ],
                dim=-1,
            )

            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i] for i in range(n - 1, 0, -1)], dim=0)
            lines += [line]

        lines = torch.cat(lines, dim=-1)
        plt.figure(figsize=(20, 20))
        show_image(lines)

# %%
with torch.no_grad():
    import random

    index1 = int(random.random() * test_x.size(0))
    index2 = int(random.random() * test_x.size(0))

    z1 = model.encoder(test_x[index1].view(1, -1))
    z2 = model.encoder(test_x[index2].view(1, -1))

    recon = model.decoder((z1 + z2) / 2).squeeze()

    show_image(test_x[index1])
    show_image(test_x[index2])
    show_image((test_x[index1] + test_x[index2]) / 2)
    show_image(recon)
